# %% [markdown]
# Assignment - 6 ( Probability Basics)

# %% [markdown]
# 1. A die is rolled. What is the probability of getting:
#
# (a) An even number
# Answer - 3/6
# In Dice, there are three even numbers: 2, 4, or 6. So probability of even number is 3 out of 6 total possible outcomes. Formula is -
#
# Probability - Number of even outcomes/Total number of outcomes.
#
# (b) A number greater than 4
# Anser - 2/6
#
# There are 2 numbers which are greater than 4 in dice. So the probability of greater number is 2 out of total possible outcomes. Formula is -
#
# Probabilty - Number of Outcomes/ Total number of outcomes

# %% [markdown]
# 2. In a class of 50 students:
#
# * 20 like Mathematics (M)
# * 15 like Science (S)
# * 5 like both subjects
#
# What is the probability that a student chosen at random likes Mathematics or Science?
#
#
# Answer - Firstly we calculate number of favorable outcomes by adding number of students who like math and science and substract the number of students who like both subject for avoid double counting.
#
# = 20+15-5 = 30
#
# Now we calculate probabilty for student who can chose random subject like mathematics or science.
#
# Probability = Number of Outcomes/Total number of Outcomes
#
#  = 30/50 = 3/5.

# %% [markdown]
# 3. : A bag has 3 red and 2 blue balls. If one ball is drawn randomly and is red, what is the probability
# that the next ball is also red (without replacement)?
#
# Answer - Remaining quantities of balls in bag are 4 now after drawn one. There are 2 of Red and 2 of Blue.
#
# So the possibilities of drawing the next ball of red colour is = 2
#
# Probability = Number of outcomes/Total number of outcomes
#
# = 2/4.

# %% [markdown]
# 4. The population of a school is divided into 60% boys and 40% girls. If you want equal representation
# of both genders in the sample, which method should you use: Simple Random Sampling or Stratified Sampling?
# Why?
#
# Answer - We use stratified sampling for the same because it allows us to ensure specific representation for different subgroups from population. By this we can divide the population in subgroups like girls and boys and easily can take meet with our requirements.

# %% [markdown]
# 5. The average height of 1000 students = 160 cm. A sample of 100 students shows an average height
# = 158 cm.
# Find the sampling error.
#
# Answer - Population Mean = 160 cm
#          Sample Mean = 158 cm
#
# Sampling error = Poulation Mean - Sample Mean
#
# =  160 - 158 = 2CM.

# %% [markdown]
# 6. The population mean salary is ₹50,000 with σ = ₹5,000. If we take a sample of 100 employees, what
# is the standard error of the mean (SEM)?
#
# Answer -Standard deviation is = 5000, and total number of employee is = 100
#
# ![image.png](data:image/png;base64,...)
#
# So the answer is 500.

# %% [markdown]
# 7. In a group of 100 students:
# 40 like Cricket (C)
# 30 like Football (F)
# 10 like both Cricket and Football
# Find the probability that a student likes at least one sport
#
# Answer = Firstly we calculate number of favrouble outcomes by  adding number of students who like cricket and football. After that substract those number of students who like both games for avoid duplicate outcome.
#
# = 40+30-10 = 60
#
# Now we calculate probabilty for students who like atleast one game.
#
# Probabilty = 60/100 = 0.6.

# %% [markdown]
# 8. From a deck of 52 cards, two cards are drawn without replacement. What is the probability that both are Aces?
#
# Answer = Total number of cards = 52m, total number of aces = 4
#
# Probability when first card drwan = 4/52
#
# Probability when second card drawn = 3/51
#
# For calculating probability that both are aces =
#
# = (4/52)*(3/51)
# = (1/13)*(1/17) = 1/221.

# %% [markdown]
# 9. A factory produces bulbs with 2% defective rate. If 5 bulbs are chosen at random, what is the probability that all are non-defective?
#
# Answer = Defective rate = 2% = 0.02
# Non defective rate = 1-0.02 = 0.98
#
# Probabilty of all 5 are non-defective
#
# ![image.png](data:image/png;base64,...)
#
#
#  So the answer is 0.9039.

# %% [markdown]
# 10. Differentiate between discrete and continuous random variables with examples
#
# Answer = Discrete random variable - it is one tat can taje on a countable number of diatinct values. These values are typically obtained by counting .
#
# Example = Number of students in classroom
#
# Continous random vaiable - It is one that can take on an infinite number of possible values are typically obtained by measuring.
#
# Example = Temperature of a room.
